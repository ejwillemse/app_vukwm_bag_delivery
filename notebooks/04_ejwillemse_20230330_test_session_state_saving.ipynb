# %%
import pickle

import os

PATH = "../data/00_session_state/"
files = os.listdir("../data/00_session_state/")
files.sort()
files
# Out:
# ['session_2023-03-30_22:35:42__user:test__Note:step 1, just loaded input data.pickle',
#  'session_2023-03-30_22:38:05__user:test__Note:step 2, jobs deselected.pickle',
#  'session_2023-03-30_22:38:30__user:test__Note:step 3, vehicles selected.pickle',
#  'session_2023-03-30_22:55:30__user:test__Note:step 4 routes generated.pickle',
#  'session_2023-03-30_22:55:59__user:test__Note:step 5 routes viewed.pickle',
#  'session_2023-03-30_22:57:45__user:test__Note:step 6 routes edit points selected.pickle',
#  'session_2023-03-30_22:58:10__user:test__Note:step 6 routes points moved.pickle',
#  'session_2023-03-30_22:58:27__user:test__Note:step 6 routes edits confirmed.pickle']

# %%
with open(PATH + files[0], "rb") as f:
    session_state = pickle.load(f)

# %%
session_state["stop_data"]
# Out:
#          Ticket No  Customer Bk  Site Bk                      Site Name  \
# 0    WCSR232758933        31456   218803                            HDW
# 1    WCSR232758935        31456   218803                            HDW
# 2    WCSR232776377       123237   427327         Accessorize Stores Ltd
# 3    WCSR232776373       123237   427327         Accessorize Stores Ltd
# 4    WCSR232765556        34006   104331               ADAM & EVE [SWR]
# ..             ...          ...      ...                            ...
# 147  WCBS232777211       187216   439194                     Wing Wing
# 148  WCSR232461130       168357   430437  Wok to Walk (15 Argll Street)
# 149  WCBS232405834       196643   473025                        Yogland
# 150  WCBS232596955       167113   376671                 Yuzefi Limited
# 151  WCSR232722780        50707   119141                     Zitron Ltd
#
#     Transport Area Code    Product Name  Quantity Created Date Required Date  \
# ...
